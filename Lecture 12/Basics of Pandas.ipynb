# %% [markdown]
# ### Using Pandas

# %%
import pandas as pd

# %%
pd.DataFrame(
# Out:
#   Cell In[3], line 1
#     pd.DataFrame(
#                  ^
# SyntaxError: incomplete input

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
wine_reviews = pd.read_csv("test_pandas.csv")

# %%
wine_reviews.head()
# Out:
#    country description                                        designation  \
# 0        0       Italy  Aromas include tropical fruit, broom, brimston...
# 1        1    Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2          US  Tart and snappy, the flavors of lime flesh and...
# 3        3          US  Pineapple rind, lemon pith and orange blossom ...
# 4        4          US  Much like the regular bottling from 2012, this...
#
#                                points  price  province           region_1  \
# 0                        Vulk� Bianco     87       NaN  Sicily & Sardinia
# 1                            Avidagos     87      15.0              Douro
# 2                                 NaN     87      14.0             Oregon
# 3                Reserve Late Harvest     87      13.0           Michigan
# 4  Vintner's Reserve Wild Child Block     87      65.0             Oregon
#
# ...

# %%
wine_reviews = pd.read_csv("winemag-data-130k-v2.csv")

# %%
wine_reviews.shape
# Out:
# (65499, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#            ...
# 65494       France
# 65495    Australia
# 65496           US
# 65497           US
# 65498        Spain
# Name: country, Length: 65499, dtype: object

# %%
# This method is preferred
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#            ...
# 65494       France
# 65495    Australia
# 65496           US
# 65497           US
# 65498        Spain
# Name: country, Length: 65499, dtype: object

# %%
wine_reviews['country'][1]
# Out:
# 'Portugal'

# %% [markdown]
# #### Accessing the information of a row entry using iloc
#
# We can list down the information of an entry using the commannd iloc

# %%
wine_reviews.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %% [markdown]
# #### We can also do index slicing

# %%
wine_reviews.iloc[:1]
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
wine_reviews.iloc[:3,1]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[:10,2]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# 5    Blackberry and raspberry aromas show a typical...
# 6    Here's a bright, informal red that opens with ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, dtype: object

# %%
wine_reviews.loc[0, 'country']
# Out:
# 'Italy'

# %% [markdown]
# #### Extended splicing in loc
# We can do spling with mu

# %%
wine_reviews.loc[:,['taster_name','taster_twitter_handle','points']]
# Out:
#               taster_name taster_twitter_handle  points
# 0           Kerin O’Keefe          @kerinokeefe      87
# 1              Roger Voss            @vossroger      87
# 2            Paul Gregutt           @paulgwine       87
# 3      Alexander Peartree                   NaN      87
# 4            Paul Gregutt           @paulgwine       87
# ...                   ...                   ...     ...
# 65494          Roger Voss            @vossroger      90
# 65495      Joe Czerwinski                @JoeCz      90
# 65496                 NaN                   NaN      90
# 65497                 NaN                   NaN      90
# 65498   Michael Schachner           @wineschach      90
#
# [65499 rows x 3 columns]

# %%
wine_reviews.country == 'Italy'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65494    False
# 65495    False
# 65496    False
# 65497    False
# 65498    False
# Name: country, Length: 65499, dtype: bool

# %%
#### Boolean Operation with DataFrame
We can attempt to see boolean condition

# %%
wine_reviews.loc[()]
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 65494       65494     France
# 65495       65495  Australia
# 65496       65496         US
# 65497       65497         US
# 65498       65498      Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 65494  Made from young vines from the Vaulorent porti...
# 65495  This is a big, fat, almost sweet-tasting Caber...
# 65496  Much improved over the unripe 2005, Fritz's 20...
# ...

# %% [markdown]
# #### Adding column to DataFrame and assign values to the whole column

# %%
wine_reviews['critic'] = 'everyone'

# %%
wine_reviews['critic']
# Out:
# 0        everyone
# 1        everyone
# 2        everyone
# 3        everyone
# 4        everyone
#            ...
# 65494    everyone
# 65495    everyone
# 65496    everyone
# 65497    everyone
# 65498    everyone
# Name: critic, Length: 65499, dtype: object

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# #### Statistical values of DataFrame
#
# We can obtain statistical data of a DataFrame using the .describe() command

# %%
wine_reviews.points.describe()
# Out:
# count    65499.000000
# mean        88.434037
# std          3.030310
# min         80.000000
# 25%         86.000000
# 50%         88.000000
# 75%         91.000000
# max        100.000000
# Name: points, dtype: float64

# %%
wine_review_mean = wine_reviews.points.mean()
print(wine_review_mean)
# Out:
# 88.43403716087269

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
def remean_points(row):
    row-points =

# %%
wine_reviews.head(10)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
# 7           7    France  This dry and restrained wine offers spice in p...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9           9    France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# ...

# %%
wine_reviews.groupby('points').points.count()
# Out:
# points
# 80      155
# 81      305
# 82      923
# 83     1442
# 84     3490
# 85     5082
# 86     6179
# 87     8872
# 88     8423
# 89     5724
# 90     7697
# 91     6016
# 92     4917
# 93     3268
# 94     1905
# 95      678
# 96      262
# 97       99
# 98       39
# 99       15
# 100       8
# Name: points, dtype: int64

# %%
wine_reviews.groupby('country').points.count()
# Out:
# country
# Argentina                  1907
# Armenia                       1
# Australia                  1177
# Austria                    1635
# Bosnia and Herzegovina        1
# Brazil                       31
# Bulgaria                     68
# Canada                      108
# Chile                      2258
# Croatia                      44
# Cyprus                        6
# Czech Republic                6
# England                      36
# France                    11174
# Georgia                      37
# Germany                    1051
# Greece                      242
# Hungary                      61
# India                         4
# Israel                      259
# Italy                     10005
# Lebanon                      20
# Luxembourg                    4
# Macedonia                     6
# Mexico                       31
# Moldova                      30
# Morocco                      11
# New Zealand                 733
# Peru                          8
# ...

# %%
wine_reviews[pd.isnull(wine_reviews.country)]
# Out:
#        Unnamed: 0 country                                        description  \
# 913           913     NaN  Amber in color, this wine has aromas of peach ...
# 3131         3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243         4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509         9509     NaN  This mouthwatering blend starts with a nose of...
# 9750         9750     NaN  This orange-style wine has a cloudy yellow-gol...
# 11150       11150     NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 11348       11348     NaN  Light and fruity, this is a wine that has some...
# 14030       14030     NaN  This Furmint, grown in marl soils, has aromas ...
# 16000       16000     NaN  Jumpy, jammy aromas of foxy black fruits are s...
# 16749       16749     NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 18075       18075     NaN  Delicate white flowers and a spin of lemon pee...
# ...

# %% [markdown]
# #### Renaming column names
#
# We can rename the columns in a DataFrame using the syntax below

# %%
wine_reviews.rename(columns={'points': 'score'})
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 65494       65494     France
# 65495       65495  Australia
# 65496       65496         US
# 65497       65497         US
# 65498       65498      Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 65494  Made from young vines from the Vaulorent porti...
# 65495  This is a big, fat, almost sweet-tasting Caber...
# 65496  Much improved over the unripe 2005, Fritz's 20...
# ...
